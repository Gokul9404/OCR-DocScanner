# %%
import pytesseract
from pytesseract import Output as PyTe_OUT
from PIL import Image
import cv2

# %%
img_file = "./Img/Img_3.jpg"

img_config = r"--psm 11 --oem 3"

img = cv2.imread(img_file)
img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

print(img.shape)
# Out:
# (4640, 3456)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
ocr_result = pytesseract.image_to_data(img, config=img_config, output_type = PyTe_OUT.DICT)

# %%
for i in ocr_result['text']:
    print(i,end=" ")
# Out:
#     r? Tas    Digs ar    ot ee    res    on    Exp    em Ne Ay    "    OTL LL tel ebb bel eb bielad s    eriment-1    11 11 Hy NN ETN ENYA TT HON NH Y ERA ED OPER UNE N EDU ED ITO NEER OD EDDUENS DOU TTEN ED ADDED UN mDOF En TLE IY ENN DTN ERI YES PY en TNEm HY    Stud    M    about PYTHON, it’s app    Pre    lication and framework    PTL th et bleh bball wv    Ota Ann vaem on amen:    hia    Python is a high-level, interpreted, interactive and object-oriented scripting language. Python    is designed to be highly readable.    aa    Python is a popular general-purpose programming language that can be used for a wide    &    ee    variety of applications. It includes high-level data structures, dynamic typing, dynamic    Ba a!    Fr    es    binding, and many more features that make it as useful for complex application    development.    ee    J    Sea we eee ee    Features of Python:    ame em ee    Open Source    Easy-to-learn    ee    Easy-to-read    Lomeae    ae    8    FN    sean    Easy-to-maintain    A broad standard library    7    es    Interactive Mode    Portable    a=    ie    See    ew 2.    Python can run on a wide variety of hardware platforms and has the same interface on    jas    Pret    Day    aed    all platforms.    es    Databases    te    =    Python provides interfaces to all major commercial databases.    GUI Programming    Xe    eo    ny system calls,    Cae    Python supports GUI applications that can be created and ported to    and the X Window    ed    libraries and windows systems, such as Windows MFC, Macinto    ?    2s    mis    system of Unix.    Scalable    Python provides a better structure and support for large programs than shell scripting.    2    lication of.    = oo on a oe ee ee    Py    thon    Uses/App    =    =    Python is known for its general-purpose nature that makes it applicable in almost every    domain of software development.    Here, specifying application areas where Python can be applied.    e Web Applications    We can use Python to develop web application    s, It provides libraries to handle internet    request, beautifulSoup,    protocols such as HTML and XML, JSON, Email processing,    Feedparser, etc.    i    sere    Yo
